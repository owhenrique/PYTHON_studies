# %%
# Aula 1 - Automação com python

# %%
# !pip install pyautogui
# !pip install pandas
# Out:
# Collecting pyautogui
#   Using cached PyAutoGUI-0.9.53.tar.gz (59 kB)
# Collecting pymsgbox
#   Using cached PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting PyTweening>=1.0.1
#   Using cached pytweening-1.0.4.tar.gz (14 kB)
# Collecting pyscreeze>=0.1.21
#   Using cached PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pygetwindow>=0.0.5
#   Using cached PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Using cached MouseInfo-0.1.3.tar.gz (10 kB)
# Collecting python3-Xlib
#   Using cached python3-xlib-0.15.tar.gz (132 kB)
# Collecting pyrect
#   Using cached PyRect-0.2.0.tar.gz (17 kB)
# Collecting pyperclip
#   Using cached pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect, python3-Xlib
#   Building wheel for pyautogui (setup.py) ... done
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36614 sha256=c72b11befdf4adecb3fef4246a09d4f9ca503e1ff1574fdae8585912649e30eb
#   Stored in directory: /home/ph/.cache/pip/wheels/d8/97/e4/d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11081 sha256=eb53182df68c5af3d32cebbd8ab096786645744660f0faa7ff55a0c08f4b0ca1
#   Stored in directory: /home/ph/.cache/pip/wheels/44/ab/20/423c3a444793767e4e41f8377bc902f77bee212e68dcce85a5
#   Building wheel for pyscreeze (PEP 517) ... done
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13009 sha256=5d2896446f4833f852d3201273f50b06dd2f754a122fbd52b8c3161eeb213282
#   Stored in directory: /home/ph/.cache/pip/wheels/a2/5b/86/99f1d8fac5d92de0ccb3f0d4ad15e3f4278baf75a9b0f20b93
#   Building wheel for PyTweening (setup.py) ... done
#   Created wheel for PyTweening: filename=pytweening-1.0.4-py3-none-any.whl size=5854 sha256=378966cadb78f891f8c1193f2d09da3d628ae9043678921248ced686f10333a2
#   Stored in directory: /home/ph/.cache/pip/wheels/a4/5d/d2/ba4c8f82163233ffaadcf383c1e34d7d92635d357d13e7b78d
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=b681a1a5996f2cd2e808d608af7256b08bde3546247957b0ac1b9b702691a1c7
#   Stored in directory: /home/ph/.cache/pip/wheels/61/73/b9/6fb1131ab36e650206e3aa0ad7a68907b41b32ac2d4f75f543
#   Building wheel for pymsgbox (PEP 517) ... done
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7406 sha256=3f7633370bc9e3184ecfe5e2c07ed4a8b6fb6229c94888216803b676557b3561
#   Stored in directory: /home/ph/.cache/pip/wheels/7f/13/8c/584c519464297d9637f9cd29fd1dcdf55e2a2cab225c76a2db
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=cba8d5249a6aa4ed4ac880a137ff1a3eb63e557f7594231b293c697b2a79a976
#   Stored in directory: /home/ph/.cache/pip/wheels/0c/09/9e/49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11196 sha256=2914eccb8174a7bc049c670f03c62d8f817f71daf6744a9e545296e1958ae431
#   Stored in directory: /home/ph/.cache/pip/wheels/25/80/fa/27bb4a1c2e21f64ec71390489d52e57b7cc8afbe79bd595c5e
#   Building wheel for python3-Xlib (setup.py) ... done
#   Created wheel for python3-Xlib: filename=python3_xlib-0.15-py3-none-any.whl size=109517 sha256=fea6995b4b5d4ac09f98790d543cac6fba4de6955a58fd76c2618dc6a0dfb95b
#   Stored in directory: /home/ph/.cache/pip/wheels/e8/f5/f4/4c7032e17a250a7327c4fa4d4807452558e04487c783bcde39
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect python3-Xlib
# Installing collected packages: python3-Xlib, pyrect, pyperclip, PyTweening, pyscreeze, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.28 python3-Xlib-0.15
# Requirement already satisfied: pandas in /home/ph/anaconda3/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ph/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ph/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /home/ph/anaconda3/lib/python3.9/site-packages (from pandas) (1.21.5)
# Requirement already satisfied: six>=1.5 in /home/ph/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pyautogui
import pyperclip
import pandas as pd
import time
import datetime

# %%
pyautogui.PAUSE = 1

# Passo 1: Entrar no sistema (no nosso caso, entrar no link)
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")

time.sleep(5)

# Passo 2: Navegar até o local do relatório (entrar na pasta Exportar)
pyautogui.click(x=390, y=341, clicks=2)
time.sleep(2)

# Passo 3: Fazer o download do relatório
pyautogui.click(x=382, y=420)
pyautogui.click(x=1710, y=224)
#pyautogui.click(x=1542, y=630, clicks=2)
time.sleep(5)

# %%
# Passo 4: Calcular os indicadores
import pandas as pd

tabela = pd.read_excel(r"/home/ph/Downloads/Vendas - Dez.xlsx")
display(tabela)
faturamento = tabela["Valor Final"].sum()
quantidade = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [7089 rows x 7 columns]

# %%
# Passo 5: Entrar no email
pyautogui.hotkey("ctrl", "t")
pyperclip.copy("https://mail.google.com/mail/u/0/#inbox")
pyautogui.hotkey("ctrl", "v")
pyautogui.press("enter")
time.sleep(5)

# Passo 6: Enviar por e-mail o resultado
pyautogui.click(x=86, y=434)
time.sleep(4)

pyautogui.write("me.pauloalmeida@gmail.com")
pyautogui.press("tab") # seleciona o email
# escreve outro email
# tab
# escreve outro email
# tab
pyautogui.press("tab") # pula pro campo de assunto
pyperclip.copy("Relatório de Vendas")
pyautogui.hotkey("ctrl", "v") # escrever o assunto
pyautogui.press("tab") #pular pro corpo do email

texto = f"""
Olá meu caro,

Este é um email contendo informações sobre o faturamento e quantidade de produtos vendidos fechados em {datetime.date.today()}.
Mas também é o primeiro email que eu mando com o programa de automação.

O faturamento é de R${faturamento:,.2f} e a quantidade de produtos vendidos é de {quantidade:,}.

Agradeço pela atenção.
Henrique, Paulo
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

# clicar no botão enviar

# apertar Ctrl Enter
pyautogui.hotkey("ctrl", "enter")
